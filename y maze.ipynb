# %%
import os
os.chdir('C:\\Users\\clair\\OneDrive\\桌面')

# %%
import pandas as pd
data = pd.read_excel('y maze.xlsx')

# %%
for i,row in data.iterrows():
    data.loc[i,'total time (s)'] = row['Time in Zone A (s)'] + row['Time in Zone B (s)'] + row['Time in Zone C (s)'] + row['Time in Zone D (s)']

# %%
data
# Out:
#    Subject      Session Treatment Novel zone First arm choice  \
# 0      a1   habituation    Normal          A                B
# 1      a2   habituation    Normal          B                A
# 2      a3   habituation    Normal          A                B
# 3      a4   habituation    Normal          A                B
# 4      a5   habituation    Normal          A                B
# 5      a6   habituation    Normal          A                B
# 6      a7   habituation    Normal          B                A
# 7      b1   habituation    Stress          B                C
# 8      b2   habituation    Stress          A                C
# 9       b3  habituation    Stress          B                A
# 10      b4  habituation    Stress          A                B
# 11      b5  habituation    Stress          B                A
# 12      b6  habituation    Stress          A                B
# 13      b7  habituation    Stress          B                A
# 14     a1          test    Normal          A                A
# 15     a2          test    Normal          B                B
# 16     a3          test    Normal          A                A
# 17     a4          test    Normal          A                A
# 18     a5          test    Normal          A                A
# 19     a6          test    Normal          A                B
# 20     a7          test    Normal          B                B
# 21     b1          test    Stress          B                A
# 22     b2          test    Stress          A                C
# 23      b3         test    Stress          B                A
# 24      b4         test    Stress          A                A
# 25      b5         test    Stress          B                C
# 26      b6         test    Stress          A                A
# 27      b7         test    Stress          B                B
#
#     novel first same  time in tube (s)  Distance in Zone C (cm)  \
# 0                NaN                 0                   987.51
# 1                NaN                 0                   706.00
# 2                NaN                 0                   899.42
# 3                NaN                 0                   627.66
# 4                NaN                 0                   693.41
# 5                NaN                 0                   561.78
# 6                NaN                 0                  1036.09
# 7                NaN               805                   191.82
# 8                NaN               600                   904.59
# 9                NaN               812                   855.86
# 10               NaN               866                   696.04
# 11               NaN               990                  1140.05
# 12               NaN               789                   859.41
# 13               NaN               749                   952.55
# 14               1.0                 0                   656.18
# 15               1.0                 0                   637.24
# 16               1.0                 0                   615.38
# 17               1.0                 0                   341.91
# 18               1.0                 0                   390.17
# 19               0.0                 0                   371.35
# 20               1.0                 0                   650.46
# 21               0.0               805                   704.03
# 22               0.0               600                   850.61
# 23               0.0               812                   847.87
# 24               1.0               866                   740.71
# 25               0.0               990                   626.82
# 26               1.0               789                   901.29
# 27               1.0               749                   641.49
#
#     Distance in Zone A (cm)  Distance in Zone B (cm)  ...  \
# 0                      0.00                   724.30  ...
# 1                    734.56                     0.00  ...
# 2                      0.00                  1065.55  ...
# 3                      0.00                   790.08  ...
# 4                     28.27                   649.42  ...
# 5                      0.00                   786.84  ...
# 6                    922.94                     0.00  ...
# 7                     81.94                     0.00  ...
# 8                      0.00                   652.92  ...
# 9                    830.78                     0.00  ...
# 10                     0.00                   995.10  ...
# 11                   710.63                     0.00  ...
# 12                     0.00                   858.72  ...
# 13                   724.49                     0.00  ...
# 14                   622.95                   544.90  ...
# 15                   345.18                   387.18  ...
# 16                   629.00                   695.71  ...
# 17                   657.40                   232.48  ...
# 18                   750.70                   187.59  ...
# 19                   479.16                   496.55  ...
# 20                   516.46                   483.86  ...
# 21                   913.34                   519.52  ...
# 22                   502.88                   427.89  ...
# 23                   552.21                   463.16  ...
# 24                   598.64                   317.86  ...
# 25                   443.54                   626.17  ...
# 26                   656.82                   662.60  ...
# 27                   503.26                   829.77  ...
#
#     1st Choice Latency (s)  distance_novel_cm  distance_familiar_cm  \
# 0                    12.69                NaN                   NaN
# 1                    10.06                NaN                   NaN
# 2                     9.56                NaN                   NaN
# 3                     6.19                NaN                   NaN
# 4                     5.12                NaN                   NaN
# 5                     9.12                NaN                   NaN
# 6                     6.62                NaN                   NaN
# 7                    23.00                NaN                   NaN
# 8                     7.94                NaN                   NaN
# 9                    42.12                NaN                   NaN
# 10                   18.62                NaN                   NaN
# 11                   21.75                NaN                   NaN
# 12                    4.06                NaN                   NaN
# 13                   14.06                NaN                   NaN
# 14                    8.69             622.95               1201.08
# 15                    5.81             387.18                982.42
# 16                    6.38             629.00               1311.09
# 17                   14.69             657.40                574.39
# 18                   11.12             750.70                577.76
# 19                    7.56             479.16                867.90
# 20                    5.75             483.86               1166.92
# 21                    2.69             519.52               1617.37
# 22                   15.75             502.88               1278.50
# 23                    0.75             463.16               1400.08
# 24                    6.69             598.64               1058.57
# 25                    4.81             626.17               1070.36
# 26                   13.88             656.82               1563.89
# 27                   28.19             829.77               1144.75
#
#     distance_novel_percentage  distance_familiar_percentage  time_novel_s  \
# 0                         NaN                           NaN           NaN
# 1                         NaN                           NaN           NaN
# 2                         NaN                           NaN           NaN
# 3                         NaN                           NaN           NaN
# 4                         NaN                           NaN           NaN
# 5                         NaN                           NaN           NaN
# 6                         NaN                           NaN           NaN
# 7                         NaN                           NaN           NaN
# 8                         NaN                           NaN           NaN
# 9                         NaN                           NaN           NaN
# 10                        NaN                           NaN           NaN
# 11                        NaN                           NaN           NaN
# 12                        NaN                           NaN           NaN
# 13                        NaN                           NaN           NaN
# 14                  34.152399                     65.847601         94.69
# 15                  28.269568                     71.730432         64.00
# 16                  32.421176                     67.578824         72.19
# 17                  53.369487                     46.630513        173.31
# 18                  56.509041                     43.490959        186.88
# 19                  35.570799                     64.429201         68.81
# 20                  29.310992                     70.689008         70.69
# 21                  24.311967                     75.688033         59.88
# 22                  28.229799                     71.770201         69.44
# 23                  24.857775                     75.142225         59.06
# 24                  36.123364                     63.876636         98.69
# 25                  36.908867                     63.091133        143.94
# 26                  29.577027                     70.422973         82.81
# 27                  42.023884                     57.976116        153.56
#
#     time_familiar_s  time_novel_percentage  time_familiar_percentage  \
# 0               NaN                    NaN                       NaN
# 1               NaN                    NaN                       NaN
# 2               NaN                    NaN                       NaN
# 3               NaN                    NaN                       NaN
# 4               NaN                    NaN                       NaN
# 5               NaN                    NaN                       NaN
# 6               NaN                    NaN                       NaN
# 7               NaN                    NaN                       NaN
# 8               NaN                    NaN                       NaN
# 9               NaN                    NaN                       NaN
# 10              NaN                    NaN                       NaN
# 11              NaN                    NaN                       NaN
# 12              NaN                    NaN                       NaN
# 13              NaN                    NaN                       NaN
# 14           172.43              35.448488                 64.551512
# 15           223.43              22.266291                 77.733709
# 16           210.43              25.543132                 74.456868
# 17           107.43              61.733276                 38.266724
# 18            88.88              67.769075                 32.230925
# 19           223.75              23.519962                 76.480038
# 20           204.06              25.728844                 74.271156
# 21           221.69              21.266470                 78.733530
# 22           231.75              23.055214                 76.944786
# 23           210.43              21.915470                 78.084530
# 24           163.94              37.577581                 62.422419
# 25           132.19              52.127621                 47.872379
# 26           207.38              28.536476                 71.463524
# 27           130.18              54.119969                 45.880031
#
#     total time (s)
# 0           314.44
# 1           315.37
# 2           305.94
# 3           297.05
# 4           322.94
# 5           300.62
# 6           320.69
# 7            86.62
# 8           336.88
# 9           301.81
# 10          313.13
# 11          306.01
# 12          305.75
# 13          338.25
# 14          306.00
# 15          310.99
# 16          305.31
# 17          302.86
# 18          301.88
# 19          308.44
# 20          318.37
# 21          301.19
# 22          320.50
# 23          305.74
# 24          305.44
# 25          305.57
# 26          305.81
# 27          303.80
#
# [28 rows x 35 columns]

# %%
data.columns
# Out:
# Index(['Subject', 'Session', 'Treatment', 'Novel zone', 'First arm choice',
#        'novel first same', 'time in tube (s)', 'Distance in Zone C (cm)',
#        'Distance in Zone A (cm)', 'Distance in Zone B (cm)',
#        'Distance in Zone D (cm)', 'Distance in Zone C (%)',
#        'Distance in Zone A (%)', 'Distance in Zone B (%)',
#        'Distance in Zone D (%)', 'Time in Zone C (s)', 'Time in Zone A (s)',
#        'Time in Zone B (s)', 'Time in Zone D (s)', 'Time in Zone C (%)',
#        'Time in Zone A (%)', 'Time in Zone B (%)', 'Time in Zone D (%)',
#        'Total Distance (cm)', '1st Arm Choice', '1st Choice Latency (s)',
#        'distance_novel_cm', 'distance_familiar_cm',
#        'distance_novel_percentage', 'distance_familiar_percentage',
#        'time_novel_s', 'time_familiar_s', 'time_novel_percentage',
#        'time_familiar_percentage', 'total time (s)'],
#       dtype='object')

# %%
data.describe()
# Out:
#        novel first same  time in tube (s)  Distance in Zone C (cm)  \
# count         14.000000         28.000000                28.000000
# mean           0.642857        400.785714               717.417857
# std            0.497245        415.633239               219.577454
# min            0.000000          0.000000               191.820000
# 25%            0.000000          0.000000               627.450000
# 50%            1.000000        300.000000               700.035000
# 75%            1.000000        805.000000               869.412500
# max            1.000000        990.000000              1140.050000
#
#        Distance in Zone A (cm)  Distance in Zone B (cm)  \
# count                28.000000                28.000000
# mean                435.898214               478.506071
# std                 323.492821               325.284215
# min                   0.000000                 0.000000
# 25%                  21.202500               221.257500
# 50%                 509.860000               508.035000
# 75%                 670.707500               702.857500
# max                 922.940000              1065.550000
#
#        Distance in Zone D (cm)  Distance in Zone C (%)  \
# count                28.000000               28.000000
# mean                173.433571               40.282857
# std                  56.104687               10.173862
# min                  18.070000               25.240000
# 25%                 141.507500               32.777500
# 50%                 168.615000               39.930000
# 75%                 207.172500               45.272500
# max                 277.730000               65.730000
#
#        Distance in Zone A (%)  Distance in Zone B (%)  Distance in Zone D (%)  \
# count               28.000000               28.000000               28.000000
# mean                24.131071               25.691786                9.479643
# std                 17.207829               17.299316                2.236233
# min                  0.000000                0.000000                5.970000
# 25%                  1.342500               15.510000                7.582500
# 50%                 27.605000               26.055000                9.080000
# 75%                 36.250000               38.760000               11.122500
# max                 51.010000               51.850000               14.350000
#
#        ...  1st Choice Latency (s)  distance_novel_cm  distance_familiar_cm  \
# count  ...               28.000000          14.000000             14.000000
# mean   ...               11.559643         586.229286           1129.648571
# std    ...                8.807514         120.717486            312.928759
# min    ...                0.750000         387.180000            574.390000
# 25%    ...                6.095000         488.615000           1001.457500
# 50%    ...                8.905000         610.795000           1155.835000
# 75%    ...               14.217500         649.865000           1302.942500
# max    ...               42.120000         829.770000           1617.370000
#
#        distance_novel_percentage  distance_familiar_percentage  time_novel_s  \
# count                  14.000000                     14.000000     14.000000
# mean                   35.116867                     64.883133     99.853571
# std                     9.734267                      9.734267     44.865522
# min                    24.311967                     43.490959     59.060000
# 25%                    28.529924                     63.287509     68.967500
# 50%                    33.286788                     66.713212     77.500000
# 75%                    36.712491                     71.470076    132.627500
# max                    56.509041                     75.688033    186.880000
#
#        time_familiar_s  time_novel_percentage  time_familiar_percentage  \
# count        14.000000              14.000000                 14.000000
# mean        180.569286              35.757705                 64.242295
# std          48.074176              16.313778                 16.313778
# min          88.880000              21.266470                 32.230925
# 25%         140.127500              23.171401                 51.509889
# 50%         205.720000              27.132660                 72.867340
# 75%         218.875000              48.490111                 76.828599
# max         231.750000              67.769075                 78.733530
#
#        total time (s)
# count       28.000000
# mean       302.407143
# std         43.482259
# min         86.620000
# 25%        303.565000
# 50%        305.875000
# 75%        314.672500
# max        338.250000
#
# [8 rows x 29 columns]

# %%
data_habituation = data[data['Session'] == 'habituation']
data_habituation = data_habituation.dropna(axis=1, how='all')
data_habituation = data_habituation[['Subject','Treatment','Total Distance (cm)','total time (s)']]

# %%
data_habituation.head()
# Out:
#   Subject Treatment  Total Distance (cm)  total time (s)
# 0     a1     Normal              1858.40          314.44
# 1     a2     Normal              1617.39          315.37
# 2     a3     Normal              2204.78          305.94
# 3     a4     Normal              1540.46          297.05
# 4     a5     Normal              1581.17          322.94

# %%
df_n = data_habituation[data_habituation['Treatment'] == 'Normal'].describe()
df_S = data_habituation[data_habituation['Treatment'] == 'Stress'].describe()
result = pd.concat([df_n, df_S], keys=['Normal', 'Stress'])
result
# Out:
#               Total Distance (cm)  total time (s)
# Normal count             7.000000        7.000000
#        mean           1783.994286      311.007143
#        std             297.030492        9.961094
#        min            1517.590000      297.050000
#        25%            1560.815000      303.280000
#        50%            1617.390000      314.440000
#        75%            2013.285000      318.030000
#        max            2204.780000      322.940000
# Stress count             7.000000        7.000000
#        mean           1637.925714      284.064286
#        std             603.148145       88.337844
#        min             291.820000       86.620000
#        25%            1740.755000      303.780000
#        50%            1813.060000      306.010000
#        75%            1938.870000      325.005000
#        max            2001.350000      338.250000

# %%
data_test = data[data['Session'] == 'test']
data_test = data_test[['Subject','Treatment','time in tube (s)',
                       'distance_novel_cm','distance_familiar_cm','distance_novel_percentage','distance_familiar_percentage',
                       'Total Distance (cm)','total time (s)',
                 'time_novel_s','time_familiar_s','time_novel_percentage','time_familiar_percentage',
                  'novel first same']]
data_test.reset_index(drop=True, inplace=True)

# %%
data_test.head()
# Out:
#   Subject Treatment  time in tube (s)  distance_novel_cm  \
# 0     a1     Normal                 0             622.95
# 1     a2     Normal                 0             387.18
# 2     a3     Normal                 0             629.00
# 3     a4     Normal                 0             657.40
# 4     a5     Normal                 0             750.70
#
#    distance_familiar_cm  distance_novel_percentage  \
# 0               1201.08                  34.152399
# 1                982.42                  28.269568
# 2               1311.09                  32.421176
# 3                574.39                  53.369487
# 4                577.76                  56.509041
#
#    distance_familiar_percentage  Total Distance (cm)  total time (s)  \
# 0                     65.847601              2084.58          306.00
# 1                     71.730432              1519.82          310.99
# 2                     67.578824              2132.88          305.31
# 3                     46.630513              1354.40          302.86
# 4                     43.490959              1471.81          301.88
#
#    time_novel_s  time_familiar_s  time_novel_percentage  \
# 0         94.69           172.43              35.448488
# 1         64.00           223.43              22.266291
# 2         72.19           210.43              25.543132
# 3        173.31           107.43              61.733276
# 4        186.88            88.88              67.769075
#
#    time_familiar_percentage  novel first same
# 0                 64.551512               1.0
# 1                 77.733709               1.0
# 2                 74.456868               1.0
# 3                 38.266724               1.0
# 4                 32.230925               1.0

# %%
df_t_n = data_test[data_test['Treatment'] == 'Normal'].describe()
df_t_S = data_test[data_test['Treatment'] == 'Stress'].describe()
result_test = pd.concat([df_t_n, df_t_S], keys=['Normal', 'Stress'])
result_test
# Out:
#               time in tube (s)  distance_novel_cm  distance_familiar_cm  \
# Normal count          7.000000           7.000000              7.000000
#        mean           0.000000         572.892857            954.508571
#        std            0.000000         126.235580            296.585037
#        min            0.000000         387.180000            574.390000
#        25%            0.000000         481.510000            722.830000
#        50%            0.000000         622.950000            982.420000
#        75%            0.000000         643.200000           1184.000000
#        max            0.000000         750.700000           1311.090000
# Stress count          7.000000           7.000000              7.000000
#        mean         801.571429         599.565714           1304.788571
#        std          117.848571         123.384679            229.421348
#        min          600.000000         463.160000           1058.570000
#        25%          769.000000         511.200000           1107.555000
#        50%          805.000000         598.640000           1278.500000
#        75%          839.000000         641.495000           1481.985000
#        max          990.000000         829.770000           1617.370000
#
#               distance_novel_percentage  distance_familiar_percentage  \
# Normal count                   7.000000                      7.000000
#        mean                   38.514780                     61.485220
#        std                    11.539492                     11.539492
#        min                    28.269568                     43.490959
#        25%                    30.866084                     55.529857
#        50%                    34.152399                     65.847601
#        75%                    44.470143                     69.133916
#        max                    56.509041                     71.730432
# Stress count                   7.000000                      7.000000
#        mean                   31.718955                     68.281045
#        std                     6.723428                      6.723428
#        min                    24.311967                     57.976116
#        25%                    26.543787                     63.483885
#        50%                    29.577027                     70.422973
#        75%                    36.516115                     73.456213
#        max                    42.023884                     75.688033
#
#               Total Distance (cm)  total time (s)  time_novel_s  \
# Normal count             7.000000        7.000000      7.000000
#        mean           1698.474286      307.692857    104.367143
#        std             322.062214        5.643881     52.786475
#        min            1354.400000      301.880000     64.000000
#        25%            1467.145000      304.085000     69.750000
#        50%            1519.820000      306.000000     72.190000
#        75%            1973.965000      309.715000    134.000000
#        max            2132.880000      318.370000    186.880000
# Stress count             7.000000        7.000000      7.000000
#        mean           2136.634286      306.864286     95.340000
#        std             207.281342        6.239650     39.081564
#        min            1887.200000      301.190000     59.060000
#        25%            1955.580000      304.620000     64.660000
#        50%            2168.020000      305.570000     82.810000
#        75%            2300.545000      305.775000    121.315000
#        max            2388.970000      320.500000    153.560000
#
#               time_familiar_s  time_novel_percentage  \
# Normal count         7.000000               7.000000
#        mean        175.772857              37.429867
#        std          55.985979              19.220982
#        min          88.880000              22.266291
#        25%         139.930000              24.531547
#        50%         204.060000              25.728844
#        75%         216.930000              48.590882
#        max         223.750000              67.769075
# Stress count         7.000000               7.000000
#        mean        185.365714              34.085543
#        std          42.653612              14.165620
#        min         130.180000              21.266470
#        25%         148.065000              22.485342
#        50%         207.380000              28.536476
#        75%         216.060000              44.852601
#        max         231.750000              54.119969
#
#               time_familiar_percentage  novel first same
# Normal count                  7.000000          7.000000
#        mean                  62.570133          0.857143
#        std                   19.220982          0.377964
#        min                   32.230925          0.000000
#        25%                   51.409118          1.000000
#        50%                   74.271156          1.000000
#        75%                   75.468453          1.000000
#        max                   77.733709          1.000000
# Stress count                  7.000000          7.000000
#        mean                  65.914457          0.428571
#        std                   14.165620          0.534522
#        min                   45.880031          0.000000
#        25%                   55.147399          0.000000
#        50%                   71.463524          0.000000
#        75%                   77.514658          1.000000
#        max                   78.733530          1.000000

# %%
result_test.to_csv('result.csv')

# %%
filtered_data = data_test[data_test['Treatment'] == 'Stress']['time in tube (s)']
filtered_data.describe()
# Out:
# count      7.000000
# mean     801.571429
# std      117.848571
# min      600.000000
# 25%      769.000000
# 50%      805.000000
# 75%      839.000000
# max      990.000000
# Name: time in tube (s), dtype: float64

# %%
#對total distance進行ANOVA，主效果不顯著
import statsmodels.api as sm
from statsmodels.formula.api import ols

model = ols('Q("Total Distance (cm)") ~ C(Treatment) * C(Session)', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

print(anova_table)
# Out:
#                                sum_sq    df         F    PR(>F)
# C(Treatment)             1.493055e+05   1.0  0.997524  0.327875
# C(Session)               2.987684e+05   1.0  1.996099  0.170543
# C(Treatment):C(Session)  5.973153e+05   1.0  3.990719  0.057207
# Residual                 3.592227e+06  24.0       NaN       NaN

# %%
#habituation時兩組的total distance無顯著差異
from scipy import stats
total_distance_normal = data_habituation[data_habituation['Treatment'] == 'Normal']['Total Distance (cm)']
total_distance_stress = data_habituation[data_habituation['Treatment'] == 'Stress']['Total Distance (cm)']

t_statistic, p_value = stats.ttest_ind(total_distance_normal, total_distance_stress)

print(f'T-statistic: {t_statistic}')
print(f'P-value: {p_value}')
# Out:
# T-statistic: 0.5748168303855411
# P-value: 0.5760336747090828

# %%
#normal組test跟habituation的Total Distance (cm)無顯著差異
from scipy import stats

total_distance_habituation_n = data_habituation[data_habituation['Treatment'] == 'Normal']['Total Distance (cm)']
total_distance_test_n = data_test[data_test['Treatment'] == 'Normal']['Total Distance (cm)']
t_statistic, p_value = stats.ttest_rel(total_distance_test_n, total_distance_habituation_n)

print(f'T-statistic: {t_statistic}')
print(f'P-value: {p_value}')
# Out:
# T-statistic: -1.3979499847496122
# P-value: 0.21162561123390122

# %%
#stress組test跟habituation的Total Distance (cm)無顯著差異
total_distance_habituation = data_habituation[data_habituation['Treatment']=='Stress']['Total Distance (cm)']
total_dtsance_test = data_test[data_habituation['Treatment']=='Stress']['Total Distance (cm)']
t_statistic, p_value = stats.ttest_rel(total_dtsance_test, total_distance_habituation)

print(f'T-statistic: {t_statistic}')
print(f'P-value: {p_value}')
# Out:
# T-statistic: 1.8039336176015457
# P-value: 0.12128985294047423

# %%
#兩組在time_novel_percentage上無顯著差異
time_nov_nc = data_test[data_test['Treatment'] == 'Normal']['time_novel_percentage']
time_nov_stress = data_test[data_test['Treatment'] == 'Stress']['time_novel_percentage']

t_statistic, p_value = stats.ttest_ind(time_nov_nc, time_nov_stress)

print(f'T-statistic: {t_statistic}')
print(f'P-value: {p_value}')
# Out:
# T-statistic: 0.3705763029504684
# P-value: 0.7174118519293118

# %%
# Create a DataFrame for the means
import seaborn as sns
import matplotlib.pyplot as plt
df_means = pd.DataFrame({
    'Group': ['Normal', 'Stress'],
    'Time in novel arm (%)': [time_nov_nc.mean(), time_nov_stress.mean()],
    'SEM': [time_nov_nc.sem(), time_nov_stress.sem()]
})

df_data_points = pd.concat([
    pd.DataFrame({'Group': 'Normal', 'Value': time_nov_nc}),
    pd.DataFrame({'Group': 'Stress', 'Value': time_nov_stress})
])

# Create a DataFrame for the individual data points
df_data = pd.DataFrame({
    'Group': ['Normal'] * len(time_nov_nc) + ['Stress'] * len(time_nov_stress),
    'Time in novel arm (%)': list(time_nov_nc) + list(time_nov_stress)
})

# Create bar plot with error bars
sns.barplot(x='Group', y='Time in novel arm (%)', yerr=df_means['SEM'], data=df_means, capsize=.1,palette='coolwarm')

# Add individual data points
sns.stripplot(x='Group', y='Value', data=df_data_points, color='black', size=4, alpha=0.5)

plt.title('Control v.s. Stress Group - Time in novel arm (%)')

plt.savefig('time_novel_percentage.png')
plt.show()

# %%
#兩組在time_novel_s上無顯著差異
time_nov_nc = data_test[data_test['Treatment'] == 'Normal']['time_novel_s']
time_nov_stress = data_test[data_test['Treatment'] == 'Stress']['time_novel_s']

t_statistic, p_value = stats.ttest_ind(time_nov_nc, time_nov_stress)

print(f'T-statistic: {t_statistic}')
print(f'P-value: {p_value}')
# Out:
# T-statistic: 0.3636388810180545
# P-value: 0.722453511020793

# %%
#兩組在distance_novel_percentage上無顯著差異
dist_nov_nc = data_test[data_test['Treatment'] == 'Normal']['distance_novel_percentage']
dist_nov_stress = data_test[data_test['Treatment'] == 'Stress']['distance_novel_percentage']

t_statistic, p_value = stats.ttest_ind(dist_nov_nc, dist_nov_stress)

print(f'T-statistic: {t_statistic}')
print(f'P-value: {p_value}')
# Out:
# T-statistic: 1.3462856011574817
# P-value: 0.2030910371394175

# %%
#兩組在distance_novel_cm上沒有顯著差異
dist_nov_nc = data_test[data_test['Treatment'] == 'Normal']['distance_novel_cm']
dist_nov_stress = data_test[data_test['Treatment'] == 'Stress']['distance_novel_cm']

t_statistic, p_value = stats.ttest_ind(dist_nov_nc, dist_nov_stress)

print(f'T-statistic: {t_statistic}')
print(f'P-value: {p_value}')
# Out:
# T-statistic: -0.39978399655607993
# P-value: 0.6963401846432435

# %%
#兩組在test時的distance_total_cm上有顯著差異
dist_total_nc = data_test[data_test['Treatment'] == 'Normal']['Total Distance (cm)']
dist_total_stress = data_test[data_test['Treatment'] == 'Stress']['Total Distance (cm)']

t_statistic, p_value = stats.ttest_ind(dist_total_nc, dist_total_stress)

print(f'T-statistic: {t_statistic}')
print(f'P-value: {p_value}')
# Out:
# T-statistic: -3.026788323810605
# P-value: 0.010529245549526292

# %%
# Create a DataFrame for the means
import seaborn as sns
import matplotlib.pyplot as plt
df_means = pd.DataFrame({
    'Group': ['Normal', 'Stress'],
    'Total Distance (cm)': [dist_total_nc.mean(), dist_total_stress.mean()],
    'SEM': [dist_total_nc.sem(), dist_total_stress.sem()]
})

# Create a DataFrame for the individual data points
df_data_points = pd.concat([
    pd.DataFrame({'Group': 'Normal', 'Value': dist_total_nc}),
    pd.DataFrame({'Group': 'Stress', 'Value': dist_total_stress})
])

# Create bar plot with error bars
sns.barplot(x='Group', y='Total Distance (cm)', yerr=df_means['SEM'], data=df_means, capsize=.1,palette='coolwarm')

# Add individual data points
sns.stripplot(x='Group', y='Value', data=df_data_points, color='black', size=4, alpha=0.5)

# Add significance line
y_max = df_data_points['Value'].max()
plt.plot([0, 0, 1, 1], [y_max + 100, y_max + 110, y_max + 110, y_max + 100], lw=1.5, c='black')
plt.text(0.5, y_max + 110, "*", ha='center', va='bottom', color='black')

# Add title
plt.title('Control vs. Stress Group - Total Distance (cm)')

plt.savefig('Control vs. Stress Group - Total Distance (cm).png')
